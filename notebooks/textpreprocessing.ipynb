# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("../scripts")

# %%
from data_loader import load_data_from_csv
from common.export_csv import exportDataVersion
import pandas as pd
import numpy as np

# %%
#Load data
df = load_data_from_csv('fullData_V2.csv')
#Data length
print(f"# of rows 'fullData_V2.csv': {len(df)}")
# Out:
# # of rows 'fullData_V2.csv': 48418

# %%
from preprocessing.translations.translation_process import process_translation

# %%
df_copy = df.head(20).copy()
process_translation(df_copy)

# %%
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)
df_copy.head(20)
# Out:
#      OccID     OccNo   Latitude   Longitude  CountryID_DisplayEng  \
# 0   150172  A17A0047  46.284740  -63.644120                CANADA
# 1   150171  A17C0081  50.772778  -96.821389                CANADA
# 2   150170  A17F0159  37.638169 -122.375428         UNITED STATES
# 3   150169  A17C0080  48.650000  -93.500000                CANADA
# 4   150168  A17C0079  66.448611  -92.464444                CANADA
# 5   150164  A17O0142  43.676667  -79.630556                CANADA
# 6   150163  A17P0098  51.221944 -123.656389                CANADA
# 7   150162  A17A0046  44.879722  -63.510278                CANADA
# 8   150161  A17P0097  51.300000 -128.816667                CANADA
# 9   150160  A17C0078  50.628056  -97.043333                CANADA
# 10  150159  A17P0096  49.194722 -123.183889                CANADA
# 11  150158  A17F0156  52.209100    7.319800               GERMANY
# 12  150157  A17O0141  43.676667  -79.630556                CANADA
# 13  150156  A17O0140  43.132500  -80.341389                CANADA
# 14  150155  A17F0155  48.000000  -50.000000  INTERNATIONAL WATERS
# 15  150154  A17P0095  49.294444 -123.111389                CANADA
# 16  150150  A17Q0095  48.856389  -67.452222                CANADA
# 17  150149  A17O0139  45.322500  -75.667222                CANADA
# 18  150148  A17C0076  49.643889 -102.285833                CANADA
# 19  150145  A17Q0094  45.679722  -74.038611                CANADA
#
#    OccClassID_DisplayEng                OccDate OccIncidentTypeID_DisplayEng  \
# 0                CLASS 5  7/10/2017 12:00:00 AM                          NaN
# 1                CLASS 5  7/10/2017 12:00:00 AM                   ENGINE (i)
# 2                CLASS 5   7/8/2017 12:00:00 AM        RISK OF COLLISION (x)
# 3                CLASS 5   7/5/2017 12:00:00 AM    DIFFICULT TO CONTROL (iv)
# 4                CLASS 5   7/2/2017 12:00:00 AM                          NaN
# 5                CLASS 5  6/24/2017 12:00:00 AM      EMERGENCY/PRIORITY (xi)
# 6                CLASS 5   7/9/2017 12:00:00 AM                          NaN
# 7                CLASS 5  6/30/2017 12:00:00 AM       LOSS OF SEPARATION (x)
# 8                CLASS 5   7/7/2017 12:00:00 AM      EMERGENCY/PRIORITY (xi)
# 9                CLASS 5   7/2/2017 12:00:00 AM        RISK OF COLLISION (x)
# 10               CLASS 5  5/22/2017 12:00:00 AM    DIFFICULT TO CONTROL (iv)
# 11               CLASS 5   7/4/2017 12:00:00 AM      EMERGENCY/PRIORITY (xi)
# 12               CLASS 5  6/26/2017 12:00:00 AM        RISK OF COLLISION (x)
# 13               CLASS 5   6/9/2017 12:00:00 AM        RISK OF COLLISION (x)
# 14               CLASS 5   7/2/2017 12:00:00 AM       UNABLE TO PERFORM (vi)
# 15               CLASS 5   7/1/2017 12:00:00 AM                          NaN
# 16               CLASS 5   7/5/2017 12:00:00 AM                          NaN
# 17               CLASS 5  6/16/2017 12:00:00 AM      EMERGENCY/PRIORITY (xi)
# 18               CLASS 5   7/2/2017 12:00:00 AM                          NaN
# 19               CLASS 5   7/3/2017 12:00:00 AM      EMERGENCY/PRIORITY (xi)
#
#    OccRegionID_DisplayEng   OccTime OccTypeID_DisplayEng  \
# 0                ATLANTIC  14:15:00             ACCIDENT
# 1                 CENTRAL  13:55:00             INCIDENT
# 2                 FOREIGN   6:56:00             INCIDENT
# 3                 CENTRAL   2:15:00             INCIDENT
# 4                 CENTRAL  22:00:00             ACCIDENT
# 5                 ONTARIO  10:30:00             INCIDENT
# 6                 PACIFIC   0:00:00             ACCIDENT
# 7                ATLANTIC   0:45:00             INCIDENT
# 8                 PACIFIC   1:10:00             INCIDENT
# 9                 CENTRAL  21:00:00             INCIDENT
# 10                PACIFIC   6:10:00             INCIDENT
# 11                FOREIGN   8:17:00             INCIDENT
# 12                ONTARIO   1:05:00             INCIDENT
# 13                ONTARIO  17:00:00             INCIDENT
# 14                FOREIGN   5:30:00             INCIDENT
# 15                PACIFIC  13:27:00             ACCIDENT
# 16                 QUEBEC  15:10:00             ACCIDENT
# 17                ONTARIO  17:30:00             INCIDENT
# 18                CENTRAL   5:02:00             ACCIDENT
# 19                 QUEBEC  21:30:00             INCIDENT
#
#    TsbInvolveID_DisplayEng    OceanID_DisplayEng PositionTypeEnum_DisplayEng  \
# 0              RESPONSIBLE                   NaN                   DDMMSS.SS
# 1              RESPONSIBLE                   NaN                   DDMMSS.SS
# 2         ACCREDITED REP 3                   NaN                   DDMMSS.SS
# 3              RESPONSIBLE                   NaN                   DDMMSS.SS
# 4              RESPONSIBLE                   NaN                   DDMMSS.SS
# 5              RESPONSIBLE                   NaN                   DDMMSS.SS
# 6              RESPONSIBLE                   NaN                   DDMMSS.SS
# 7              RESPONSIBLE                   NaN                   DDMMSS.SS
# 8              RESPONSIBLE   NORTH PACIFIC OCEAN                   DDMMSS.SS
# 9              RESPONSIBLE                   NaN                   DDMMSS.SS
# 10             RESPONSIBLE                   NaN                   DDMMSS.SS
# 11             RESPONSIBLE                   NaN                   DDMMSS.SS
# 12             RESPONSIBLE                   NaN                   DDMMSS.SS
# 13             RESPONSIBLE                   NaN                   DDMMSS.SS
# 14             RESPONSIBLE  NORTH ATLANTIC OCEAN                   DDMMSS.SS
# 15             RESPONSIBLE                   NaN                   DDMMSS.SS
# 16             RESPONSIBLE                   NaN                   DDMMSS.SS
# 17             RESPONSIBLE                   NaN                   DDMMSS.SS
# 18             RESPONSIBLE                   NaN                   DDMMSS.SS
# 19             RESPONSIBLE                   NaN                   DDMMSS.SS
#
#    ProvinceID_DisplayEng       InitTSBNotifDate ReportedByID_DisplayEng  \
# 0   PRINCE EDWARD ISLAND  7/10/2017 12:00:00 AM       OWNER OF AIRCRAFT
# 1               MANITOBA  7/10/2017 12:00:00 AM                OPERATOR
# 2             CALIFORNIA   7/9/2017 12:00:00 AM             FOREIGN AIB
# 3                ONTARIO   7/7/2017 12:00:00 AM                OPERATOR
# 4                NUNAVUT   7/5/2017 12:00:00 AM                OPERATOR
# 5                ONTARIO  6/24/2017 12:00:00 AM              NAV CANADA
# 6       BRITISH COLUMBIA   7/9/2017 12:00:00 AM                OPERATOR
# 7            NOVA SCOTIA  6/30/2017 12:00:00 AM              NAV CANADA
# 8                    NaN   7/7/2017 12:00:00 AM              NAV CANADA
# 9               MANITOBA   7/3/2017 12:00:00 AM                OPERATOR
# 10      BRITISH COLUMBIA   7/7/2017 12:00:00 AM                OPERATOR
# 11                   NaN   7/4/2017 12:00:00 AM                OPERATOR
# 12               ONTARIO  6/26/2017 12:00:00 AM              NAV CANADA
# 13               ONTARIO  6/27/2017 12:00:00 AM                OPERATOR
# 14                   NaN   7/4/2017 12:00:00 AM                OPERATOR
# 15      BRITISH COLUMBIA   7/5/2017 12:00:00 AM                OPERATOR
# 16                QUEBEC   7/5/2017 12:00:00 AM                OPERATOR
# 17               ONTARIO  6/16/2017 12:00:00 AM              NAV CANADA
# 18          SASKATCHEWAN   7/2/2017 12:00:00 AM                  POLICE
# 19                QUEBEC   7/3/2017 12:00:00 AM              NAV CANADA
#
#    RespRegionID_DisplayEng                                            Summary  \
# 0                 ATLANTIC  C-IICE a privately operated Quad City Challeng...
# 1                  CENTRAL  C-GWCP a Piper PA-32-300 aircraft operated by ...
# 2              HEAD OFFICE  C-FKCK an Airbus 320-200 aircraft operated by ...
# 3                  CENTRAL  C-GJVC a Fairchild SA227-DC aircraft operated ...
# 4                  CENTRAL  C-GGSV an Aerospatiale AS 350 B-2 aircraft ope...
# 5                  ONTARIO  N12028 an Airbus 319-100 aircraft operated by ...
# 6                  PACIFIC  C-GGCT a privately operated Cessna 182M aircra...
# 7                 ATLANTIC  N910XJ a Bombardier CL-600-2D24 (CRJ 900) airc...
# 8                  PACIFIC  N174DZ a Boeing 767-300 aircraft operated by D...
# 9                  CENTRAL  C-FBIY a Cessna 182F aircraft operated by Skyd...
# 10                 PACIFIC  C-FDMB a Boeing 737-800 aircraft operated by W...
# 11             HEAD OFFICE  C-FGZI a McDonnell Douglas A4N aircraft operat...
# 12                 ONTARIO  TF-ISV a Boeing 757-200 aircraft operated by I...
# 13                 ONTARIO  C-GYTL a Fairchild SA227-CC aircraft operated ...
# 14             HEAD OFFICE  C-GHLQ a Boeing 767-300 aircraft operated by A...
# 15                 PACIFIC  C-GQKN a de Havilland DHC-6-200 Twin Otter air...
# 16                  QUEBEC  C-FKZC, a Cessna T210N operated by Orizon Avia...
# 17                 ONTARIO  C-FGXO a Beech C90A aircraft operated by the G...
# 18                 CENTRAL  C-FSWK a privately operated Champion 7EC aircr...
# 19                  QUEBEC  C-GSCA, a Boeing 767-300 operated by Air Canad...
#
#    InjuriesEnum_DisplayEng DeployedEnum_DisplayEng RegistrationNo  \
# 0                      Yes                      No         C-IICE
# 1                       No                      No         C-GWCP
# 2                       No                      No         C-FKCK
# 3                      Yes                      No         C-GJVC
# 4                       No                      No         C-GGSV
# 5                       No                      No         N12028
# 6                      Yes                      No         C-GGCT
# 7                       No                      No         N910XJ
# 8                       No                      No         N174DZ
# 9                       No                      No         C-GHXS
# 10                      No                      No         C-FDMB
# 11                      No                      No         C-FGZI
# 12                      No                      No         TF-ISV
# 13                      No                      No         C-GYTL
# 14                     Yes                      No         C-GHLQ
# 15                      No                      No         C-GQKN
# 16                     Yes                      No         C-FKZC
# 17                      No                      No         C-FGXO
# 18                      No                      No         C-FSWK
# 19                      No                      No         C-GSCA
#
#    AircraftTypeID_DisplayEng      AircraftMakeID_DisplayEng  \
# 0        ADVANCED ULTRALIGHT                     CHALLENGER
# 1                  AEROPLANE                          PIPER
# 2                  AEROPLANE                         AIRBUS
# 3                  AEROPLANE                      FAIRCHILD
# 4                 HELICOPTER                   AEROSPATIALE
# 5                  AEROPLANE                         AIRBUS
# 6                  AEROPLANE                         CESSNA
# 7                  AEROPLANE                       CANADAIR
# 8                  AEROPLANE                         BOEING
# 9                  AEROPLANE                         CESSNA
# 10                 AEROPLANE                         BOEING
# 11                 AEROPLANE              MCDONNELL DOUGLAS
# 12                 AEROPLANE                         BOEING
# 13                 AEROPLANE                      FAIRCHILD
# 14                 AEROPLANE                         BOEING
# 15                 AEROPLANE                   DE HAVILLAND
# 16                 AEROPLANE                         CESSNA
# 17                 AEROPLANE                          BEECH
# 18                 AEROPLANE  CHAMPION AIRCRAFT CORPORATION
# 19                 AEROPLANE                         BOEING
#
#               OrganizationID_DisplayEng OperatorTypeID_DisplayEng  \
# 0                                   NaN                   PRIVATE
# 1                       MHA ENTERPRISES                COMMERCIAL
# 2                            AIR CANADA                COMMERCIAL
# 3             BEARSKIN LAKE AIR SERVICE                COMMERCIAL
# 4               GREAT SLAVE HELICOPTERS                COMMERCIAL
# 5                     AMERICAN AIRLINES                COMMERCIAL
# 6                                   NaN                   PRIVATE
# 7                          ENDEAVOR AIR                COMMERCIAL
# 8                       DELTA AIR LINES                COMMERCIAL
# 9                    INTERLAKE AVIATION                COMMERCIAL
# 10                              WESTJET                COMMERCIAL
# 11  DISCOVERY AIR DEFENCE SERVICES INC.                COMMERCIAL
# 12                           ICELANDAIR                COMMERCIAL
# 13            BEARSKIN LAKE AIR SERVICE                COMMERCIAL
# 14                     AIR CANADA ROUGE                COMMERCIAL
# 15                          HARBOUR AIR                COMMERCIAL
# 16          ORIZON AVIATION QUÉBEC INC.                COMMERCIAL
# 17                     TRANSPORT CANADA                COMMERCIAL
# 18                                  NaN                   PRIVATE
# 19                     AIR CANADA ROUGE                COMMERCIAL
#
#            WeightCategoryID_DisplayEng LandingGearID_DisplayEng  \
# 0         0-2250 KG       (0-4960 LBS)           TRICYCLE FIXED
# 1         0-2250 KG       (0-4960 LBS)           TRICYCLE FIXED
# 2   27001-272000 KG (59526-599650 LBS)     TRICYCLE ALL RETRACT
# 3    5701-27000 KG   (12566-59525 LBS)     TRICYCLE ALL RETRACT
# 4         0-2250 KG       (0-4960 LBS)                     SKID
# 5   27001-272000 KG (59526-599650 LBS)     TRICYCLE ALL RETRACT
# 6         0-2250 KG       (0-4960 LBS)           TRICYCLE FIXED
# 7   27001-272000 KG (59526-599650 LBS)     TRICYCLE ALL RETRACT
# 8   27001-272000 KG (59526-599650 LBS)     TRICYCLE ALL RETRACT
# 9         0-2250 KG       (0-4960 LBS)           TRICYCLE FIXED
# 10  27001-272000 KG (59526-599650 LBS)     TRICYCLE ALL RETRACT
# 11   5701-27000 KG   (12566-59525 LBS)     TRICYCLE ALL RETRACT
# 12  27001-272000 KG (59526-599650 LBS)     TRICYCLE ALL RETRACT
# 13   5701-27000 KG   (12566-59525 LBS)     TRICYCLE ALL RETRACT
# 14  27001-272000 KG (59526-599650 LBS)     TRICYCLE ALL RETRACT
# 15    2251-5700 KG    (4961-12565 LBS)                    FLOAT
# 16        0-2250 KG       (0-4960 LBS)     TRICYCLE ALL RETRACT
# 17    2251-5700 KG    (4961-12565 LBS)     TRICYCLE ALL RETRACT
# 18        0-2250 KG       (0-4960 LBS)         TAIL WHEEL FIXED
# 19  27001-272000 KG (59526-599650 LBS)     TRICYCLE ALL RETRACT
#
#    WakeTurbulenceCategoryID_DisplayEng  YearOfManuf  NumberOfEngine  \
# 0                                LIGHT         2015               1
# 1                                LIGHT         1968               1
# 2                               MEDIUM         1991               2
# 3                               MEDIUM         1996               2
# 4                                LIGHT         1989               1
# 5                               MEDIUM         2015               2
# 6                                LIGHT         1969               1
# 7                               MEDIUM         2007               2
# 8                                HEAVY         1998               2
# 9                                LIGHT         1975               1
# 10                              MEDIUM         2014               2
# 11                              MEDIUM         1976               1
# 12                              MEDIUM         1999               2
# 13                              MEDIUM         1993               2
# 14                               HEAVY         2001               2
# 15                               LIGHT         1968               2
# 16                               LIGHT         1981               1
# 17                               LIGHT         1989               2
# 18                               LIGHT         1956               1
# 19                               HEAVY         1991               2
#
#    DamageLevelID_DisplayEng OperationTypeID_DisplayEng ICAODepart
# 0               SUBSTANTIAL            PLEASURE/TRAVEL        NaN
# 1                     MINOR              AIR TRANSPORT       CYST
# 2                      NONE              AIR TRANSPORT       CYYZ
# 3                      NONE              AIR TRANSPORT       CYAG
# 4               SUBSTANTIAL              AIR TRANSPORT        NaN
# 5                      NONE              AIR TRANSPORT       CYYZ
# 6               SUBSTANTIAL            PLEASURE/TRAVEL        NaN
# 7                      NONE              AIR TRANSPORT       KJFK
# 8                      NONE              AIR TRANSPORT       KSEA
# 9                      NONE            PLEASURE/TRAVEL       CYGM
# 10                     NONE              AIR TRANSPORT       CYEG
# 11                     NONE                      OTHER       ETMN
# 12                     NONE              AIR TRANSPORT       CYYZ
# 13                     NONE              AIR TRANSPORT       CYFD
# 14                     NONE              AIR TRANSPORT       CYUL
# 15              SUBSTANTIAL              AIR TRANSPORT       CYWH
# 16              SUBSTANTIAL               PHOTO/SURVEY       CYQB
# 17                     NONE                   TRAINING       CYOW
# 18              SUBSTANTIAL            PLEASURE/TRAVEL        NaN
# 19                     NONE              AIR TRANSPORT       LGAV
